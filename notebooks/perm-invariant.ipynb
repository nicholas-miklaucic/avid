# %%
import jax
import jax.numpy as jnp
import pandas as pd
import seaborn as sns
import flax.linen as nn
import numpy as np
import rho_plus as rp

theme, cs = rp.mpl_setup(is_dark=False)

# %%
df = pd.read_pickle('precomputed/jarvis_dft3d_cleaned/dataframe.pkl')
sns.kdeplot(df['magmom'])
# Out:
# <Axes: xlabel='magmom', ylabel='Density'>

# %%
xx = jnp.array(np.random.randn(1000))

sns.kdeplot(nn.leaky_relu((3 * (xx - 0.8))), ls='--', cut=0)
ax = sns.kdeplot(df['magmom'], cut=0)
ax.set_xlim(0, 20)
# Out:
# (0.0, 20.0)

# %%
xx = jnp.array(np.random.randn(1000))

sns.kdeplot(nn.leaky_relu((3 * (xx - 1.2))), ls='--', cut=0)
sns.kdeplot(df['bandgap'], cut=0)
# Out:
# <Axes: xlabel='bandgap', ylabel='Density'>
